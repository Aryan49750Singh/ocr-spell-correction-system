# %% [markdown]
# <a href="https://colab.research.google.com/github/Aryan49750Singh/ocr-spell-correction-system/blob/main/ocr_spell_correction_system.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Spelling Correction**

# %% [markdown]
# ### **Import the dependency**

# %%
# Import the dependency
from textblob import TextBlob

# enter incorrect text
incorrect_text = 'i am goood'

# %%
# Using textBlb library
textBlb = TextBlob(incorrect_text)

# %%
# Print correct string
textBlb.correct().string
# Out:
# 'i am good'

# %% [markdown]
# ## **Another way to do this**

# %%
! pip install pyspellchecker

# %%
from spellchecker import SpellChecker

spell = SpellChecker()

text = "Data scienttist is a very goood career. you shoulld learne"

dict_of_autocorrect_words = {}
for i in spell.unknown(text.split()):
    dict_of_autocorrect_words[i] = spell.correction(i)

print(f'The AUTOCORRECT suggestions are Mis-spelled words are {dict_of_autocorrect_words}')

temp = text.split()
res = []
for wrd in temp:

    res.append(dict_of_autocorrect_words.get(wrd, wrd))

res = ' '.join(res)

print(res)
# Out:
# The AUTOCORRECT suggestions are Mis-spelled words are {'scienttist': 'scientist', 'learne': 'learn', 'shoulld': 'should', 'goood': 'good', 'career.': 'career'}
# Data scientist is a very good career you should learn

# %% [markdown]
# # **Text Extraction**

# %% [markdown]
# ### **Import the dependency**

# %%
# Import the dependency
# !pip install easyocr

# %%
# Import the dependency
import matplotlib.pyplot as plt
import cv2
import easyocr
from pylab import rcParams
from IPython.display import Image
rcParams['figure.figsize'] = 8, 16

# %%
# Reading the Image
reader = easyocr.Reader(['en'])

img = '/content/drive/MyDrive/Data Set/Sample_image.jpg'

# Showing the image
Image(img)
# Out:
# WARNING:easyocr.easyocr:Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
# Reading the text from the Image
output = reader.readtext(img)
output
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# [([[np.int32(32), np.int32(28)],
#    [np.int32(260), np.int32(28)],
#    [np.int32(260), np.int32(61)],
#    [np.int32(32), np.int32(61)]],
#   'Ethos; Pathos, Logos',
#   np.float64(0.6231116201163462)),
#  ([[np.int32(35), np.int32(69)],
#    [np.int32(259), np.int32(69)],
#    [np.int32(259), np.int32(87)],
#    [np.int32(35), np.int32(87)]],
#   'Pathos is a Greek word that means',
#   np.float64(0.8100479085037456)),
#  ([[np.int32(265), np.int32(71)],
#    [np.int32(339), np.int32(71)],
#    [np.int32(339), np.int32(87)],
#    [np.int32(265), np.int32(87)]],
#   'experience',
#   np.float64(0.9999484293381574)),
#  ([[np.int32(35), np.int32(88)],
#    [np.int32(363), np.int32(88)],
#    [np.int32(363), np.int32(107)],
# ...

# %%
# Text correction
text = ''
for i in range(len(output)):
  text =text +'\n'+ output[i][1]

print(text)
# Out:
# Ethos; Pathos, Logos
# Pathos is a Greek word that means
# experience
# Pathos is the third pillar in persuasive writing which
# aims at involving
# writer $ appeal to emotion: A lot of
# human actions tend to be led by emotions rather
# than facts:
# 0GrammarBrain
